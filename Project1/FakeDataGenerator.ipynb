# %% [markdown]
# <a href="https://colab.research.google.com/github/Shikher-jain/PYTHON-Projects/blob/master/FakeDataGenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
from faker import Faker
import pandas as pd

# Initialize Faker
fake = Faker()

# Ask user for number of entries
n = int(input("Enter number of records: "))

# Create a list to hold dictionaries
data_list = []

for _ in range(n):
    record = {
        'Name': fake.name(),
        'Email': fake.email(),
        'Address': fake.address(),
        'Phone': fake.phone_number()
    }
    data_list.append(record)

# Convert list of dictionaries to a DataFrame
df = pd.DataFrame(data_list)

# Display the DataFrame
print(df)

# Optional: save to
# df.to_csv("fake_data.csv", index=False)
# Out:
# Enter number of records: 34
#                      Name                        Email  \
# 0      Christopher Mclean     matthewellis@example.org
# 1   Mrs. Kathryn Adams MD  robertmaldonado@example.com
# 2          Michelle Parks      michaelhill@example.net
# 3             Anthony Cox     watsonjoshua@example.net
# 4         Stacy Carpenter       hicksjulia@example.net
# 5        Matthew Mitchell  phillipsannette@example.com
# 6           Jessica Brown     tuckerbrenda@example.net
# 7         Joshua Schaefer    williamgolden@example.com
# 8            Paige Garcia   kellykatherine@example.net
# 9            Amber Wright   darrylgonzalez@example.org
# 10           Robert Hogan     cookjonathan@example.com
# 11             Kathy Cook  davidsonmatthew@example.org
# 12               Kim Wood        william37@example.com
# 13        Brooke Campbell  williamsjeffrey@example.com
# 14            Lori Flores     debraparsons@example.com
# ...

# %%
# @title

# %%
# !pip install faker
